# %%
'''
第10章 面向对象 VS Matlab Style
第11章 子图-subplot
第12章 多图-figure
第13章 网格
第14章 图例_legend
第15章 坐标轴范围
第16章 坐标轴刻度
第17章 添加坐标轴
第18章 注释
第19章 文字
第20章 Tex公式
第21章 工具栏
第22章 区域填充
第23章 形状
第24章 样式-美化
第25章 极坐标
'''
# Out:
# '\n第10章 面向对象 VS Matlab Style\n第11章 子图-subplot\n第12章 多图-figure\n第13章 网格\n第14章 图例_legend\n第15章 坐标轴范围\n第16章 坐标轴刻度\n第17章 添加坐标轴\n第18章 注释\n第19章 文字\n第20章 Tex公式\n第21章 工具栏\n第22章 区域填充\n第23章 形状\n第24章 样式-美化\n第25章 极坐标\n'

# %%
'''
第10章 面向对象 VS Matlab Style http://matplotlib.org/api/pyplot_summary.html

'''
# Out:
# '\n第10章 面向对象 VS Matlab Style http://matplotlib.org/api/pyplot_summary.html\n\n'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
# %matplotlib inline

# %%
from pylab import *
x = arange(0,10,1)
y = randn(len(x))
plot(x,y)
title('pylab')
show()

# %%
x = np.arange(0,10,1)
y = np.random.randn(len(x))
plt.plot(x,y)
plt.title('pyplot')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
l, = plt.plot(x,y)
t = ax.set_title('object oriented')
plt.show()

# %%
'''
Matplotlib 对象简介
FigureCanvas
Figure
Axes

fig = plot.figure()
ax = fig.add_subplot(111) # 
参数一: 子图总行数
参数二:子图总列数
参数三:子图位置
'''
# Out:
# '\nMatplotlib 对象简介\nFigureCanvas\nFigure\nAxes\n\nfig = plot.figure()\nax = fig.add_subplot(111) # \n参数一: 子图总行数\n参数二:子图总列数\n参数三:子图位置\n'

# %%
'''
第11章 子图-subplot
'''
# Out:
# '\n第11章 子图-subplot\n'

# %%
x = np.arange(1,100,1)
fig = plt.figure()
ax = fig.add_subplot(221)
ax.plot(x,x)
ax.set_title('y=x')

ax2 = fig.add_subplot(222)
ax2.plot(x,-x)
ax2.set_title('y=-x')


ax3 = fig.add_subplot(223)
ax3.plot(x,x**2)
ax3.set_title('y=x^2')

ax4 = fig.add_subplot(224)
ax4.plot(x,np.log(x))
ax4.set_title('y=log(x)')

plt.show()

# %%
'''
第12章 多图-figure
'''
# Out:
# '\n第12章 多图-figure\n'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([3,2,1],[3,2,1])

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.plot([2,3,4],[7,5,1])

plt.show()

# %%
'''
第13章 网格
'''
data = np.arange(1,10,1)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(data,data)
# ax.grid(True) || plt.grid()
plt.grid(color='g',linestyle='-')
plt.show()

# %%
data = np.arange(1,10,1)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(data,data)
plt.grid(color='g',linestyle='-.')
plt.show()

# %%
data = np.arange(1,10,1)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(data,data)
plt.grid(color='g',linestyle='--',linewidth=2)
plt.show()

# %%
'''
第14章 图例_legend

http://matplotlib.org/api/legend_api.html

label
plt.legend()
'''
# Out:
# '\n第14章 图例_legend\n\nhttp://matplotlib.org/api/legend_api.html\n\nlabel\nplt.legend()\n'

# %%
'''
'best'         : 0, (only implemented for axes legends)
'upper right'  : 1,
'upper left'   : 2,
'lower left'   : 3,
'lower right'  : 4,
'right'        : 5,
'center left'  : 6,
'center right' : 7,
'lower center' : 8,
'upper center' : 9,
'center'       : 10,

'''
# Out:
# "\n'best'         : 0, (only implemented for axes legends)\n'upper right'  : 1,\n'upper left'   : 2,\n'lower left'   : 3,\n'lower right'  : 4,\n'right'        : 5,\n'center left'  : 6,\n'center right' : 7,\n'lower center' : 8,\n'upper center' : 9,\n'center'       : 10,\n\n"

# %%
data = np.arange(1,5,0.5)

plt.plot(data,data*2,label='y=2x')
plt.plot(data,data**2,label='y=x^2')
plt.plot(data,data**3,label='y=x^3')
plt.legend(loc=10)
# plt.legend(loc=0) # loc=[0,1,2,3...10]
plt.show()

# %%
data = np.arange(1,5,0.5)

plt.plot(data,data*2,label='y=2x')
plt.plot(data,data**2,label='y=x^2')
plt.plot(data,data**3,label='y=x^3')
plt.legend(ncol=3)
# plt.legend(loc=0) # loc=[0,1,2,3...10]
plt.show()

# %%
data = np.arange(1,5,0.5)

plt.plot(data,data*2)
plt.plot(data,data**2)
plt.plot(data,data**3)

plt.legend(['y=2x','y=x^2','y=x^3'],ncol=3)
plt.show()

# %%
x = np.arange(1,5,1)
# print(x)
fig = plt.figure()
ax = fig.add_subplot(111)
l, = plt.plot(x,x*x)
l.set_label('label via method')
# ax.lenged()
plt.show()

# %%
x = np.arange(1,5,1)
# print(x)
fig = plt.figure()
ax = fig.add_subplot(111)
l, = plt.plot(x,x*x,label='label via method')
ax.legend(loc=0)
plt.show()

# %%
'''
第15章 坐标轴范围
'''
# Out:
# '\n第15章 坐标轴范围\n'

# %%
x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.show()

# %%
x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.axis()
plt.axis([-8,9,15,80])
plt.show()

# %%
x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.xlim([-8,9])
plt.show()

# %%
x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.ylim([20,90])
plt.show()

# %%
x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.xlim(xmin=-5,xmax=8)
plt.show()

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xlim

matplotlib.pyplot.xlim(*args, **kwargs)
Get or set the x limits of the current axes.

xmin, xmax = xlim()   # return the current xlim
xlim( (xmin, xmax) )  # set the xlim to xmin, xmax
xlim( xmin, xmax )    # set the xlim to xmin, xmax
If you do not specify args, you can pass the xmin and xmax as kwargs, e.g.:

xlim(xmax=3) # adjust the max leaving min unchanged
xlim(xmin=1) # adjust the min leaving max unchanged
Setting limits turns autoscaling off for the x-axis.

The new axis limits are returned as a length 2 tuple.

'''

x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.xlim(xmin=-5)
plt.show()

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.ylim

matplotlib.pyplot.ylim(*args, **kwargs)
Get or set the y-limits of the current axes.

ymin, ymax = ylim()   # return the current ylim
ylim( (ymin, ymax) )  # set the ylim to ymin, ymax
ylim( ymin, ymax )    # set the ylim to ymin, ymax
If you do not specify args, you can pass the ymin and ymax as kwargs, e.g.:

ylim(ymax=3) # adjust the max leaving min unchanged
ylim(ymin=1) # adjust the min leaving max unchanged
Setting limits turns autoscaling off for the y-axis.

The new axis limits are returned as a length 2 tuple.

'''
x = np.arange(-10,11,1)
plt.plot(x,x**2)
plt.ylim(ymin=5)
plt.show()

# %%
'''
http://matplotlib.org/api/axes_api.html#matplotlib.axes.Axes.set_xlim
'''

x = np.arange(-10,11,1)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,x**2)
ax.set_xlim([-5,8])
ax.set_title('ax.set_xlim()')
plt.show()

# %%
'''
第16章 坐标轴刻度
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.locator_params
'''
# Out:
# '\n第16章 坐标轴刻度\nhttp://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.locator_params\n'

# %%
'''
matplotlib.pyplot.locator_params(axis='both', tight=None, **kwargs)
Control behavior of tick locators.

Keyword arguments:

axis
[‘x’ | ‘y’ | ‘both’] Axis on which to operate; default is ‘both’.
tight
[True | False | None] Parameter passed to autoscale_view(). Default is None, for no change.
Remaining keyword arguments are passed to directly to the set_params() method.

Typically one might want to reduce the maximum number of ticks and use tight bounds when plotting small subplots, for example:

ax.locator_params(tight=True, nbins=4)
Because the locator is involved in autoscaling, autoscale_view() is called automatically after the parameters are changed.

This presently works only for the MaxNLocator used by default on linear axes, but it may be generalized.

'''
# Out:
# "\nmatplotlib.pyplot.locator_params(axis='both', tight=None, **kwargs)\nControl behavior of tick locators.\n\nKeyword arguments:\n\naxis\n[‘x’ | ‘y’ | ‘both’] Axis on which to operate; default is ‘both’.\ntight\n[True | False | None] Parameter passed to autoscale_view(). Default is None, for no change.\nRemaining keyword arguments are passed to directly to the set_params() method.\n\nTypically one might want to reduce the maximum number of ticks and use tight bounds when plotting small subplots, for example:\n\nax.locator_params(tight=True, nbins=4)\nBecause the locator is involved in autoscaling, autoscale_view() is called automatically after the parameters are changed.\n\nThis presently works only for the MaxNLocator used by default on linear axes, but it may be generalized.\n\n"

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
plt.show()

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
plt.locator_params(tight=True,nbins=5)
plt.show()

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
ax = plt.gca()
ax.locator_params(tight=True,nbins=5)
plt.show()

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
ax = plt.gca()
ax.locator_params('y',tight=True,nbins=5)
plt.show()

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
ax = plt.gca()
ax.locator_params('both',tight=True,nbins=5)
plt.show()

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
ax = plt.gca()
ax.locator_params(axis=('both'),tight=True,nbins=5)
plt.show()

# %%
x = np.arange(1,11,1)
plt.plot(x,x)
ax = plt.gca()
ax.locator_params(axis='yx',tight=True,nbins=5)
plt.show()

# %%
import datetime
start = datetime.datetime(2015,1,1)
stop = datetime.datetime.now()
delta = datetime.timedelta(days=1)
dates = mpl.dates.drange(start,stop,delta)

date_format = mpl.dates.DateFormatter('%Y-%m')
y = np.arange(len(dates))
ax = plt.gca()
ax.xaxis.set_major_formatter(date_format)

ax.plot_date(dates,y,linestyle='-',marker='')

plt.show()

# %%
import datetime
fig = plt.figure()
start = datetime.datetime(2015,1,1)
stop = datetime.datetime.now()
delta = datetime.timedelta(days=1)
dates = mpl.dates.drange(start,stop,delta)

date_format = mpl.dates.DateFormatter('%Y-%m')
y = np.arange(len(dates))
ax = plt.gca()
ax.xaxis.set_major_formatter(date_format)

ax.plot_date(dates,y,linestyle='-',marker='')
fig.autofmt_xdate()
plt.show()

# %%
'''
第17章 添加坐标轴
'''
# Out:
# '\n第17章 添加坐标轴\n'

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xlabel

matplotlib.pyplot.xlabel(s, *args, **kwargs)
Set the x axis label of the current axis.

Default override is:

override = {
    'fontsize'            : 'small',
    'verticalalignment'   : 'top',
    'horizontalalignment' : 'center'
    }
See also
text()
For information on how override and the optional args work

'''
# Out:
# "\nhttp://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.xlabel\n\nmatplotlib.pyplot.xlabel(s, *args, **kwargs)\nSet the x axis label of the current axis.\n\nDefault override is:\n\noverride = {\n    'fontsize'            : 'small',\n    'verticalalignment'   : 'top',\n    'horizontalalignment' : 'center'\n    }\nSee also\ntext()\nFor information on how override and the optional args work\n\n"

# %%
x = np.arange(2,20,1)
y1 = x*x
y2 = np.log(x)
plt.plot(y1,x)
plt.plot(y2,x)
plt.show()

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.twinx
matplotlib.pyplot.twinx(ax=None)
Make a second axes that shares the x-axis. The new axes will overlay ax (or the current axes if ax is None). 
The ticks for ax2 will be placed on the right, and the ax2 instance is returned.

See also
examples/api_examples/two_scales.py
For an example
'''
# Out:
# '\nhttp://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.twinx\nmatplotlib.pyplot.twinx(ax=None)\nMake a second axes that shares the x-axis. The new axes will overlay ax (or the current axes if ax is None). \nThe ticks for ax2 will be placed on the right, and the ax2 instance is returned.\n\nSee also\nexamples/api_examples/two_scales.py\nFor an example\n'

# %%
x = np.arange(2,20,1)
y1 = x*x
y2 = np.log(x)
plt.plot(x,y1)
ax = plt.twinx()
ax.plot(x,y2)
plt.show()

# %%
x = np.arange(2,20,1)
y1 = x*x
y2 = np.log(x)
fig = plt.figure()
ax1 = fig.add_subplot(111)
plt.plot(y1,x)

ax2 = ax1.twinx()
ax2.plot(y2,x,color='r')

ax1.set_xlabel('Compare Y1 and Y2')

ax2.set_ylabel('Y2')
plt.show()

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.twiny
matplotlib.pyplot.twiny(ax=None)
Make a second axes that shares the y-axis. The new axis will overlay ax (or the current axes if ax is None). 
The ticks for ax2 will be placed on the top, and the ax2 instance is returned.

'''
# Out:
# '\nhttp://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.twiny\nmatplotlib.pyplot.twiny(ax=None)\nMake a second axes that shares the y-axis. The new axis will overlay ax (or the current axes if ax is None). \nThe ticks for ax2 will be placed on the top, and the ax2 instance is returned.\n\n'

# %%
x = np.arange(2,20,1)
y1 = x*x
y2 = np.log(x)

plt.plot(y1,x,color='b')
plt.twiny()
plt.plot(y2,x,color='r')
plt.show()

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.ylabel

matplotlib.pyplot.ylabel(s, *args, **kwargs)
Set the y axis label of the current axis.

Defaults override is:

override = {
   'fontsize'            : 'small',
   'verticalalignment'   : 'center',
   'horizontalalignment' : 'right',
   'rotation'='vertical' : }
See also
text()
For information on how override and the optional args work.
'''
# Out:
# "\nhttp://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.ylabel\n\nmatplotlib.pyplot.ylabel(s, *args, **kwargs)\nSet the y axis label of the current axis.\n\nDefaults override is:\n\noverride = {\n   'fontsize'            : 'small',\n   'verticalalignment'   : 'center',\n   'horizontalalignment' : 'right',\n   'rotation'='vertical' : }\nSee also\ntext()\nFor information on how override and the optional args work.\n"

# %%
'''
第18章 注释
 http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.annotate 
'''
# Out:
# '\n第18章 注释\n http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.annotate \n'

# %%
x = np.arange(-10,11,1)
y = x**2
plt.plot(x,y)
plt.annotate('This is the bottom',color='r',xy=(0,1),xytext=(0,20)
             ,arrowprops=dict(facecolor='r',headlength=8
                              ,headwidth=30,width=10))
plt.show()

# %%
x = np.arange(-10,11,1)
y = x**2
plt.plot(x,y)
plt.annotate('The point is (5,25)',color='r',xy=(5,25),xytext=(-5,60)
             ,arrowprops=dict(facecolor='r',headlength=8
                              ,headwidth=30,width=10))
plt.show()

# %%
'''
第19章 文字
 http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.text 

matplotlib.pyplot.text(x, y, s, fontdict=None, withdash=False, **kwargs)
Add text to the axes.

Add text in string s to axis at location x, y, data coordinates.

Parameters:	
x, y : scalars

data coordinates

s : string

text

fontdict : dictionary, optional, default: None

A dictionary to override the default text properties. If fontdict is None, the defaults are determined by your rc parameters.

withdash : boolean, optional, default: False

Creates a TextWithDash instance instead of a Text instance.

Other Parameters:
 	
kwargs : Text properties.

Other miscellaneous text parameters.

'''
# Out:
# '\n第19章 文字\n http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.text \n\nmatplotlib.pyplot.text(x, y, s, fontdict=None, withdash=False, **kwargs)\nAdd text to the axes.\n\nAdd text in string s to axis at location x, y, data coordinates.\n\nParameters:\t\nx, y : scalars\n\ndata coordinates\n\ns : string\n\ntext\n\nfontdict : dictionary, optional, default: None\n\nA dictionary to override the default text properties. If fontdict is None, the defaults are determined by your rc parameters.\n\nwithdash : boolean, optional, default: False\n\nCreates a TextWithDash instance instead of a Text instance.\n\nOther Parameters:\n \t\nkwargs : Text properties.\n\nOther miscellaneous text parameters.\n\n'

# %%
'''
Examples

Individual keyword arguments can be used to override any given parameter:

>>> text(x, y, s, fontsize=12)
The default transform specifies that text is in data coords, alternatively, you can specify text in axis coords (0,0 is lower-left and 1,1 is upper-right). The example below places text in the center of the axes:

>>> text(0.5, 0.5,'matplotlib', horizontalalignment='center',
...      verticalalignment='center',
...      transform=ax.transAxes)
You can put a rectangular box around the text instance (e.g., to set a background color) by using the keyword bbox. bbox is a dictionary of Rectangle properties. For example:

>>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))
'''
# Out:
# "\nExamples\n\nIndividual keyword arguments can be used to override any given parameter:\n\n>>> text(x, y, s, fontsize=12)\nThe default transform specifies that text is in data coords, alternatively, you can specify text in axis coords (0,0 is lower-left and 1,1 is upper-right). The example below places text in the center of the axes:\n\n>>> text(0.5, 0.5,'matplotlib', horizontalalignment='center',\n...      verticalalignment='center',\n...      transform=ax.transAxes)\nYou can put a rectangular box around the text instance (e.g., to set a background color) by using the keyword bbox. bbox is a dictionary of Rectangle properties. For example:\n\n>>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))\n"

# %%
x = np.arange(-10,11,1)
y = x**2
fig = plt.figure()
ax = fig.add_subplot(111)
plt.text(0.5, 0.5,'matplotlib', horizontalalignment='center',verticalalignment='center',transform=ax.transAxes)
plt.plot(x,y)

# %%
x = np.arange(-10,11,1)
y = x**2
fig = plt.figure()
ax = fig.add_subplot(111)
plt.text(0.5, 10,'matplotlib', horizontalalignment='center', bbox=dict(facecolor='red', alpha=0.5))
plt.plot(x,y)

# %%
'''
set_family(fontname)
Set the font family. May be either a single string, or a list of strings in decreasing priority. Each string may be either a real font name or a generic font class name. If the latter, the specific font names will be looked up in the matplotlibrc file.

ACCEPTS: [FONTNAME | ‘serif’ | ‘sans-serif’ | ‘cursive’ | ‘fantasy’ |
‘monospace’ ]
'''
# Out:
# '\nset_family(fontname)\nSet the font family. May be either a single string, or a list of strings in decreasing priority. Each string may be either a real font name or a generic font class name. If the latter, the specific font names will be looked up in the matplotlibrc file.\n\nACCEPTS: [FONTNAME | ‘serif’ | ‘sans-serif’ | ‘cursive’ | ‘fantasy’ |\n‘monospace’ ]\n'

# %%
'''
set_style(fontstyle)
Set the font style.

ACCEPTS: [ ‘normal’ | ‘italic’ | ‘oblique’]
'''
# Out:
# '\nset_style(fontstyle)\nSet the font style.\n\nACCEPTS: [ ‘normal’ | ‘italic’ | ‘oblique’]\n'

# %%
'''
set_weight(weight)
Set the font weight.

ACCEPTS: [a numeric value in range 0-1000 | ‘ultralight’ | ‘light’ |
‘normal’ | ‘regular’ | ‘book’ | ‘medium’ | ‘roman’ | ‘semibold’ | ‘demibold’ | ‘demi’ | ‘bold’ | ‘heavy’ | ‘extra bold’ | ‘black’ ]
'''
# Out:
# '\nset_weight(weight)\nSet the font weight.\n\nACCEPTS: [a numeric value in range 0-1000 | ‘ultralight’ | ‘light’ |\n‘normal’ | ‘regular’ | ‘book’ | ‘medium’ | ‘roman’ | ‘semibold’ | ‘demibold’ | ‘demi’ | ‘bold’ | ‘heavy’ | ‘extra bold’ | ‘black’ ]\n'

# %%
'''
set_bbox(rectprops)
Draw a bounding box around self. rectprops are any settable properties for a FancyBboxPatch, e.g., facecolor=’red’, alpha=0.5.

t.set_bbox(dict(facecolor=’red’, alpha=0.5))
The default boxstyle is ‘square’. The mutation scale of the FancyBboxPatch is set to the fontsize.

ACCEPTS: FancyBboxPatch prop dict

'''
# Out:
# '\nset_bbox(rectprops)\nDraw a bounding box around self. rectprops are any settable properties for a FancyBboxPatch, e.g., facecolor=’red’, alpha=0.5.\n\nt.set_bbox(dict(facecolor=’red’, alpha=0.5))\nThe default boxstyle is ‘square’. The mutation scale of the FancyBboxPatch is set to the fontsize.\n\nACCEPTS: FancyBboxPatch prop dict\n\n'

# %%
x = np.arange(-10,11,1)
y = x**2
plt.text(-3, 10,'matplotlib',family='serif',size=20,color='r')
plt.text(-3, 20,'matplotlib',family='cursive',size=20,color='b')
plt.text(-3, 30,'matplotlib',family='fantasy',size=20,color='g')
plt.text(-3, 40,'matplotlib',family='sans-serif',size=30,color='y')
plt.text(-3, 40,'matplotlib',family='sans-serif',size=30,color='y')
plt.text(-3, 50,'matplotlib',family='sans-serif',size=30,color='y',style='oblique')
plt.text(-3, 60,'matplotlib',family='sans-serif',size=30,color='y',style='oblique',weight='demi')
plt.text(-3, 75,'matplotlib',family='sans-serif',size=30,color='y',style='oblique',weight='demi'
         ,bbox=dict(facecolor='r',alpha=0.6))

plt.plot(x,y)

# %%
x = np.arange(-10,11,1)
y = x**2

plt.plot(x,y)

# %%
'''
第20章 Tex公式
 http://matplotlib.org/users/mathtext.html 
 http://matplotlib.org/users/mathtext.html#symbols 
'''
# Out:
# '\n第20章 Tex公式\n http://matplotlib.org/users/mathtext.html \n http://matplotlib.org/users/mathtext.html#symbols \n'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_xlim([1,7])
ax.set_ylim([1,7])
ax.text(2,5,size=20,s=r'$ \alpha_i \beta_j\pi\lambda_w $')

ax.text(2,3,size=20,s=r'$ \lim_{x \rightarrow y} \frac{1}{x^3}$')

ax.text(4,5,size=20,s=r'$ \sin(0) =\cos(\frac{\pi}{2}) $')
ax.text(4,3,size=20,s=r'$ \sqrt[4]{x} =\sqrt{y} $')

plt.show()

# %%
'''
第21章 工具栏
'''
# Out:
# '\n第21章 工具栏\n'

# %%
'''
第22章 区域填充
 http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill 
 http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill_between 
 http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill_betweenx
'''
# Out:
# '\n第22章 区域填充\n http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill \n http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill_between \n http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill_betweenx\n'

# %%
'''
 http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill
 matplotlib.pyplot.fill(*args, **kwargs)
Plot filled polygons.

Call signature:

fill(*args, **kwargs)
args is a variable length argument, allowing for multiple x, y pairs with an optional color format string; see plot() for details on the argument parsing. For example, to plot a polygon with vertices at x, y in blue.:

ax.fill(x,y, 'b' )
An arbitrary number of x, y, color groups can be specified:

ax.fill(x1, y1, 'g', x2, y2, 'r')
Return value is a list of Patch instances that were added.

The same color strings that plot() supports are supported by the fill format string.

If you would like to fill below a curve, e.g., shade a region between 0 and y along x, use fill_between()

The closed kwarg will close the polygon when True (default).

kwargs control the Polygon properties:
'''
# Out:
# "\n http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill\n matplotlib.pyplot.fill(*args, **kwargs)\nPlot filled polygons.\n\nCall signature:\n\nfill(*args, **kwargs)\nargs is a variable length argument, allowing for multiple x, y pairs with an optional color format string; see plot() for details on the argument parsing. For example, to plot a polygon with vertices at x, y in blue.:\n\nax.fill(x,y, 'b' )\nAn arbitrary number of x, y, color groups can be specified:\n\nax.fill(x1, y1, 'g', x2, y2, 'r')\nReturn value is a list of Patch instances that were added.\n\nThe same color strings that plot() supports are supported by the fill format string.\n\nIf you would like to fill below a curve, e.g., shade a region between 0 and y along x, use fill_between()\n\nThe closed kwarg will close the polygon when True (default).\n\nkwargs control the Polygon properties:\n"

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
plt.plot(x,y1,x,y2,color='black')
plt.show()

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
fig = plt.figure()
ax = fig.gca()
ax.plot(x,y1,x,y2,color='g')
plt.show()

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
fig = plt.figure()
ax = fig.gca()
ax.fill(x,y1,'b',alpha=0.3)
ax.fill(x,y2,'r',alpha=0.3)
plt.show()

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
plt.fill(x,y1,'b',alpha=0.3)
plt.fill(x,y2,'g',alpha=0.3)
plt.show()

# %%
'''
http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill_between
matplotlib.pyplot.fill_between(x, y1, y2=0, where=None, interpolate=False, step=None, hold=None, data=None, **kwargs)
Make filled polygons between two curves.

Create a PolyCollection filling the regions between y1 and y2 where where==True

Parameters:	
x : array

An N-length array of the x data

y1 : array

An N-length array (or scalar) of the y data

y2 : array

An N-length array (or scalar) of the y data

where : array, optional

If None, default to fill between everywhere. If not None, it is an N-length numpy boolean array and the fill will only happen over the regions where where==True.

interpolate : bool, optional

If True, interpolate between the two lines to find the precise point of intersection. Otherwise, the start and end points of the filled region will only occur on explicit values in the x array.

step : {‘pre’, ‘post’, ‘mid’}, optional

If not None, fill with step logic.
'''
# Out:
# '\nhttp://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.fill_between\nmatplotlib.pyplot.fill_between(x, y1, y2=0, where=None, interpolate=False, step=None, hold=None, data=None, **kwargs)\nMake filled polygons between two curves.\n\nCreate a PolyCollection filling the regions between y1 and y2 where where==True\n\nParameters:\t\nx : array\n\nAn N-length array of the x data\n\ny1 : array\n\nAn N-length array (or scalar) of the y data\n\ny2 : array\n\nAn N-length array (or scalar) of the y data\n\nwhere : array, optional\n\nIf None, default to fill between everywhere. If not None, it is an N-length numpy boolean array and the fill will only happen over the regions where where==True.\n\ninterpolate : bool, optional\n\nIf True, interpolate between the two lines to find the precise point of intersection. Otherwise, the start and end points of the filled region will only occur on explicit values in the x array.\n\nstep : {‘pre’, ‘post’, ‘mid’}, optional\n\nIf not None, fill with ste
# ...

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
fig = plt.figure()
ax = fig.gca()
ax.plot(x,y1,'r',alpha=0.3)
ax.plot(x,y2,'b',alpha=0.3)

ax.fill_between(x,y1,y2,where=y1>y2,facecolor='y',interpolate=False)
ax.fill_between(x,y1,y2,where=y1<y2,facecolor='g',interpolate=False)
plt.show()

# %%
x = np.linspace(0,5*np.pi,1000)
# print(x)
y1 = np.sin(x)
y2 = np.sin(2*x)
fig = plt.figure()
ax = fig.gca()
ax.plot(x,y1,'r',alpha=0.3)
ax.plot(x,y2,'b',alpha=0.3)

ax.fill_between(x,y1,y2,where=y1>y2,facecolor='y',interpolate=True)
ax.fill_between(x,y1,y2,where=y1<y2,facecolor='g',interpolate=True)

plt.show()

# %%
'''
第23章 形状 http://matplotlib.org/api/patches_api.html 


'''
import matplotlib.patches as mpatches

# %%
fig ,ax = plt.subplots()
xy1 = np.array([0.2,0.2])
xy2 = np.array([0.15,0.68])
xy3 = np.array([0.8,0.2])
xy4 = np.array([0.8,0.8])
circle = mpatches.Circle(xy1,0.05)
ax.add_patch(circle)


rect = mpatches.Rectangle(xy2,0.3,0.2,color='r')
ax.add_patch(rect)

polygon = mpatches.RegularPolygon(xy3,5,0.1,color='g')
ax.add_patch(polygon)

ellipse = mpatches.Ellipse(xy4,0.4,0.2,color='y')
ax.add_patch(ellipse)

ax.grid(True) # plt.grid(True)
plt.axis('equal')

plt.show()

# %%
'''
http://matplotlib.org/api/patches_api.html#matplotlib.patches.Ellipse

class matplotlib.patches.Ellipse(xy, width, height, angle=0.0, **kwargs)
Bases: matplotlib.patches.Patch

A scale-free ellipse.

xy
center of ellipse
width
total length (diameter) of horizontal axis
height
total length (diameter) of vertical axis
angle
rotation in degrees (anti-clockwise)
'''
# Out:
# '\nhttp://matplotlib.org/api/patches_api.html#matplotlib.patches.Ellipse\n\nclass matplotlib.patches.Ellipse(xy, width, height, angle=0.0, **kwargs)\nBases: matplotlib.patches.Patch\n\nA scale-free ellipse.\n\nxy\ncenter of ellipse\nwidth\ntotal length (diameter) of horizontal axis\nheight\ntotal length (diameter) of vertical axis\nangle\nrotation in degrees (anti-clockwise)\n'

# %%
fig, ax= plt.subplots()
ellipse = mpatches.Ellipse((0.4,0.5),0.5,0.2)
ellipse = mpatches.Ellipse((0.4,0.5),0.5,0.2,color='g')
ax.add_patch(ellipse)
ax.grid(True)
plt.axis('equal')
plt.show()

# %%
'''
 http://matplotlib.org/api/patches_api.html#matplotlib.patches.Circle
 
class matplotlib.patches.Circle(xy, radius=5, **kwargs)
Bases: matplotlib.patches.Ellipse

A circle patch.

Create true circle at center xy = (x, y) with given radius. Unlike CirclePolygon which is a polygonal approximation,
this uses Bézier splines and is much closer to a scale-free circle.

'''
# Out:
# '\n http://matplotlib.org/api/patches_api.html#matplotlib.patches.Circle\n \nclass matplotlib.patches.Circle(xy, radius=5, **kwargs)\nBases: matplotlib.patches.Ellipse\n\nA circle patch.\n\nCreate true circle at center xy = (x, y) with given radius. Unlike CirclePolygon which is a polygonal approximation,\nthis uses Bézier splines and is much closer to a scale-free circle.\n\n'

# %%
fig,ax = plt.subplots()
circle = mpatches.Circle((0,0),4.6,color='y')
ax.add_patch(circle)
ax.grid(True)
plt.axis('equal')
plt.show()

# %%
'''
http://matplotlib.org/api/patches_api.html#matplotlib.patches.Rectangle

class matplotlib.patches.Rectangle(xy, width, height, angle=0.0, **kwargs)
Bases: matplotlib.patches.Patch

Draw a rectangle with lower left at xy = (x, y) with specified width and height.

angle
rotation in degrees (anti-clockwise)
fill is a boolean indicating whether to fill the rectangle

'''
# Out:
# '\nhttp://matplotlib.org/api/patches_api.html#matplotlib.patches.Rectangle\n\nclass matplotlib.patches.Rectangle(xy, width, height, angle=0.0, **kwargs)\nBases: matplotlib.patches.Patch\n\nDraw a rectangle with lower left at xy = (x, y) with specified width and height.\n\nangle\nrotation in degrees (anti-clockwise)\nfill is a boolean indicating whether to fill the rectangle\n\n'

# %%
fig,ax = plt.subplots()
rect = mpatches.Rectangle((1,1),4,5,angle=45)
ax.add_patch(rect)
ax.grid(True)
plt.axis('equal')
plt.show()

# %%
'''
http://matplotlib.org/api/patches_api.html#matplotlib.patches.RegularPolygon

class matplotlib.patches.RegularPolygon(xy, numVertices, radius=5, orientation=0, **kwargs)
Bases: matplotlib.patches.Patch

A regular polygon patch.

Constructor arguments:

xy
A length 2 tuple (x, y) of the center.
numVertices
the number of vertices.
radius
The distance from the center to each of the vertices.
orientation
rotates the polygon (in radians).

'''
# Out:
# '\nhttp://matplotlib.org/api/patches_api.html#matplotlib.patches.RegularPolygon\n\nclass matplotlib.patches.RegularPolygon(xy, numVertices, radius=5, orientation=0, **kwargs)\nBases: matplotlib.patches.Patch\n\nA regular polygon patch.\n\nConstructor arguments:\n\nxy\nA length 2 tuple (x, y) of the center.\nnumVertices\nthe number of vertices.\nradius\nThe distance from the center to each of the vertices.\norientation\nrotates the polygon (in radians).\n\n'

# %%
fig,ax = plt.subplots()
reg = mpatches.RegularPolygon((1,2),6,radius=5, orientation=0)
ax.add_patch(reg)
ax.grid(True)
plt.axis('equal')
plt.show()

# %%
'''
第24章 样式-美化
'''
# Out:
# '\n第24章 样式-美化\n'

# %%
plt.rcParams['axes.color_cycle']
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# ['b', 'g', 'r', 'c', 'm', 'y', 'k']

# %%
plt.rcParams['axes.prop_cycle']
# Out:
# cycler('color', ['b', 'g', 'r', 'c', 'm', 'y', 'k'])

# %%
x = np.arange(0,10)
y = np.arange(0,10)
ncolors = len(plt.rcParams['axes.prop_cycle'])
shift = np.linspace(0,10,ncolors)
for s in shift:
    plt.plot(x,y+s,'-')
plt.show()

# %%
def def_display():
    x,y = np.random.normal(size=(2,100))
    ax1.plot(x,y,'o')
    ncolors = len(plt.rcParams['axes.prop_cycle'])
    shift = np.linspace(0,10,ncolors)
    x = np.arange(0,10)
    y = np.arange(0,10)
    for s in shift:
        ax2.plot(x,y+s,'-')
    
def display_bar():
    x = np.arange(5)
    y1,y2,y3 = np.random.randint(1,25,size=(3,5))
    width = 0.25

    ax3.bar(x,y1,width,color=plt.rcParams['axes.color_cycle'][0])
    ax3.bar(x + width,y2,width,color=plt.rcParams['axes.color_cycle'][1])
    ax3.bar(x + 2*width,y3,width,color=plt.rcParams['axes.color_cycle'][2])


def display_circle():
    for i ,color in enumerate(plt.rcParams['axes.color_cycle']):
        xy = np.random.normal(size=2)
        ax4.add_patch(plt.Circle(xy,radius=0.3,color=color))
    ax4.axis('equal')
    





def display_all():
    def_display() 
    display_bar()
    display_circle()
   

fig,axes = plt.subplots(ncols=2,nrows=2)
ax1,ax2,ax3,ax4 = axes.ravel()
display_all()
plt.show()
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
plt.style.available
# Out:
# ['seaborn-deep',
#  'seaborn-talk',
#  'dark_background',
#  'seaborn-darkgrid',
#  'ggplot',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-white',
#  'classic',
#  'seaborn-poster',
#  'grayscale',
#  'seaborn-dark-palette',
#  'seaborn-pastel',
#  'bmh',
#  'seaborn-notebook',
#  'seaborn-muted',
#  'seaborn-whitegrid',
#  'seaborn-colorblind',
#  'seaborn-paper',
#  'seaborn-bright',
#  'seaborn-dark']

# %%
styles = plt.style.available
print(styles)

for style in styles:
    plt.style.use(style)
    fig,axes = plt.subplots(ncols=2,nrows=2)
    ax1,ax2,ax3,ax4 = axes.ravel()
    display_all()
    plt.show()
# Out:
# ['seaborn-deep', 'seaborn-talk', 'dark_background', 'seaborn-darkgrid', 'ggplot', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-white', 'classic', 'seaborn-poster', 'grayscale', 'seaborn-dark-palette', 'seaborn-pastel', 'bmh', 'seaborn-notebook', 'seaborn-muted', 'seaborn-whitegrid', 'seaborn-colorblind', 'seaborn-paper', 'seaborn-bright', 'seaborn-dark']
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
'''
第25章 极坐标

'''
# Out:
# '\n第25章 极坐标\n\n'

# %%
x = np.arange(0.5,3,0.5)
print(x)
theta = [0,np.pi/2,np.pi,3*np.pi/2,2*np.pi,]

ax = plt.subplot(111,projection='polar')
ax.plot(theta,x,color='r',linewidth=3)

ax.grid(True)

plt.show()
# Out:
# [ 0.5  1.   1.5  2.   2.5]

# %%
n = 8
x = np.empty(9)
x.fill(3)

# x = np.arange(0.5,3,0.5)
print(x)

pi_two = np.pi * 2

theta = [0/n,pi_two/n,pi_two*2/n,pi_two*3/n,pi_two*4/n,pi_two*5/n,pi_two*6/n,pi_two*7/n,pi_two*8/n]

print(theta)
ax = plt.subplot(111,projection='polar')
ax.plot(theta,x,color='r',linewidth=3)

ax.grid(True)

plt.show()
# Out:
# [ 3.  3.  3.  3.  3.  3.  3.  3.  3.]
# [0.0, 0.7853981633974483, 1.5707963267948966, 2.356194490192345, 3.141592653589793, 3.9269908169872414, 4.71238898038469, 5.497787143782138, 6.283185307179586]
